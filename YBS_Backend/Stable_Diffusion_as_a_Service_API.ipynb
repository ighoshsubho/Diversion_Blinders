# %% [markdown]
# <a href="https://colab.research.google.com/github/ighoshsubho/Diversion_Blinders/blob/main/Stable_Diffusion_as_a_Service_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffuzers -qqqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 34.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 KB 37.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.3/761.3 KB 48.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 KB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 82.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 KB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 85.8 MB/s eta 0:00:00
# ...

# %%
# !diffuzers api --help
# Out:
# usage: diffuzers <command> [<args>] api
#        [-h]
#        [--output OUTPUT]
#        [--port PORT]
#        [--host HOST]
#        [--device DEVICE]
#        [--workers WORKERS]
#
# ✨ Run
# diffuzers
# api
#
# optional arguments:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   --output OUTPUT
#     Output path
#     is
#     optional,
#     but if
#     provided,
#     all
#     generations
#     will automa
#     tically be
#     saved to
#     this path.
#   --port PORT
#     Port to run
#     the app on
#   --host HOST
#     Host to run
#     the app on
#   --device DEVICE
#     Device to
#     use, e.g.
#     cpu, cuda,
#     cuda:0, mps
#     (for m1
#     mac) etc.
#   --workers WORKERS
#     Number of
#     workers to
#     use

# %%
#Environment Variable

# %%
# %env X2IMG_MODEL=stabilityai/stable-diffusion-2-1
# Out:
# env: X2IMG_MODEL=stabilityai/stable-diffusion-2-1

# %%
# %env DEVICE=cuda
# Out:
# env: DEVICE=cuda

# %%
# !diffuzers api --port 10000  & npx localtunnel --port 10000
# Out:
# npx: installed 22 in 2.719s
# your url is: https://lazy-suits-fail-34-69-220-63.loca.lt
# INFO:     Started server process [5175]
# 2023-01-12 17:34:10.262 INFO    uvicorn.error: Started server process [5175]
# INFO:     Waiting for application startup.
# 2023-01-12 17:34:10.262 INFO    uvicorn.error: Waiting for application startup.
# > INFO    @@@@@ Starting Diffuzes API @@@@@
# > INFO    Text2Image Model: stabilityai/stable-diffusion-2-1
# > INFO    Text2Image Pipeline: Vanilla
# > INFO    Inpainting Model: None
# > INFO    Device: cuda
# > INFO    Output Path: None
# > INFO    Token Identifier:
# > INFO    Token Embeddings URL:
# > INFO    Loading x2img model...
#
# Downloading:   0%|          | 0.00/539 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 539/539 [00:00<00:00, 644kB/s]
#
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 342/342 [00:00<00:00, 353kB/s]
#
# ...
